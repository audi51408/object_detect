# %%
import os
import glob
import pandas as pd
import io
import xml.etree.ElementTree as ET
import argparse
import random

# %%
def xml_to_csv(path):
    xml_list = []
    className = os.listdir(path)[1:]
    for i in className:
        for xml_file in glob.glob(path +"/"+i +'/*.xml'):
            tree = ET.parse(xml_file)
            root = tree.getroot()
            filename = root.find('FileName').text
            xmin = root.find('DefectBound').find('X1').text
            ymin = root.find('DefectBound').find('Y1').text
            xmax = root.find('DefectBound').find('X2').text
            ymax = root.find('DefectBound').find('Y2').text
            width = str(int(xmax) - int(xmin))
            height = str(int(ymax) - int(ymin))
            value = (filename,
                    width,
                    height,
                    i,
                    xmin,
                    ymin,
                    xmax,
                    ymax,
                    )
            xml_list.append(value)


    column_name = ['filename', 'width', 'height',
                'className', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df

# %%
xml = xml_to_csv("東捷科技_20220504_ADC_釋出資料集_origin")

# %%
xml
# Out:
#                  filename width height className xmin ymin xmax ymax
# 0     A114D042CA08004_Dft    18     15       I_R   18  461   36  476
# 1     A114D077AL05001_Dft     6     20       I_R   35  454   41  474
# 2     A114E00NAN08002_Dft     2      5       I_R   36  473   38  478
# 3     A114E036CA07001_Dft     5      8       I_R   34  470   39  478
# 4     A114F00MAG06001_Dft     6      7       I_R   32  470   38  477
# ...                   ...   ...    ...       ...  ...  ...  ...  ...
# 2497  A115U076BV02001_Dft    21     20      Udev   33  411   54  431
# 2498  A115U079CE04001_Dft    21     21      Udev   32  413   53  434
# 2499  A115U082BQ08001_Dft    23     24      Udev   82  483  105  507
# 2500  A115U0A5AN03001_Dft     2      3      Udev  149  406  151  409
# 2501  A115V00PCD02001_Dft    29      2      Udev   80  518  109  520
#
# [2502 rows x 8 columns]

# %%
from collections import namedtuple
def split(df, group):
    data = namedtuple('data', ['filename', 'object'])
    gb = df.groupby(group)
    return [data(filename, gb.get_group(x)) for filename, x in zip(gb.groups.keys(), gb.groups)]
class_Name = split(xml, 'filename')

# %%
for name in class_Name:
    print(name.object.className.values[0])
    print(name.filename)
    print(name)
    print("--------")
# Out:
# Udev
# A114B068AG01001_Dft
# data(filename='A114B068AG01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2002  A114B068AG01001_Dft     6      9      Udev   98  421  104  430)
# --------
# TP
# A114B068AG01002_Dft
# data(filename='A114B068AG01002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1501  A114B068AG01002_Dft     9     15        TP   18  463   27  478)
# --------
# TP
# A114B068AG01004_Dft
# data(filename='A114B068AG01004_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1502  A114B068AG01004_Dft    15     13        TP    0  483   15  496)
# --------
# TP
# A114B068AG03002_Dft
# data(filename='A114B068AG03002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1503  A114B068AG03002_Dft     5      3        TP    0  408    5  411)
# --------
# PP
# A114D023AB01001_Dft
# data(filename='A114D023AB01001_Dft', object=                filename width height className xmin ymin xmax ymax
# 500  A114D023AB01001_Dft    48     57        PP   14   86   62  143)
# --------
# PP
# A114D023AB02001_Dft
# data(filename='A114D023AB02001_Dft', object=                filename width height className xmin ymin xmax ymax
# 501  A114D023AB02001_Dft    41     35        PP    1  443   42  478)
# --------
# PP
# A114D03PCG01001_Dft
# data(filename='A114D03PCG01001_Dft', object=                filename width height className xmin ymin xmax ymax
# 502  A114D03PCG01001_Dft    16     12        PP  178  447  194  459)
# --------
# TP
# A114D03PCG03003_Dft
# data(filename='A114D03PCG03003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1504  A114D03PCG03003_Dft    15     10        TP    5  299   20  309)
# --------
# TP
# A114D03PCG03004_Dft
# data(filename='A114D03PCG03004_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1505  A114D03PCG03004_Dft     8     15        TP   13  244   21  259)
# --------
# TP
# A114D03PCG04002_Dft
# data(filename='A114D03PCG04002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1506  A114D03PCG04002_Dft     8     12        TP   18  469   26  481)
# --------
# PP
# A114D03PCG05001_Dft
# data(filename='A114D03PCG05001_Dft', object=                filename width height className xmin ymin xmax ymax
# 503  A114D03PCG05001_Dft    28     26        PP   18  467   46  493)
# --------
# TP
# A114D03PCG07001_Dft
# data(filename='A114D03PCG07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1507  A114D03PCG07001_Dft    17     20        TP    9  368   26  388)
# --------
# TP
# A114D03PCG08004_Dft
# data(filename='A114D03PCG08004_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1508  A114D03PCG08004_Dft     4      6        TP    0   97    4  103)
# --------
# I_R
# A114D042CA08004_Dft
# data(filename='A114D042CA08004_Dft', object=              filename width height className xmin ymin xmax ymax
# 0  A114D042CA08004_Dft    18     15       I_R   18  461   36  476)
# --------
# TP
# A114D06XAT04001_Dft
# data(filename='A114D06XAT04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1509  A114D06XAT04001_Dft    11     11        TP  160  144  171  155)
# --------
# TP
# A114D06XAT05001_Dft
# data(filename='A114D06XAT05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1510  A114D06XAT05001_Dft    16     12        TP    7  114   23  126)
# --------
# TP
# A114D077AG05003_Dft
# data(filename='A114D077AG05003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1511  A114D077AG05003_Dft     7      4        TP   21  448   28  452)
# --------
# TP
# A114D077AJ01001_Dft
# data(filename='A114D077AJ01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1512  A114D077AJ01001_Dft    26     25        TP   26  450   52  475)
# --------
# TP
# A114D077AJ05002_Dft
# data(filename='A114D077AJ05002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1513  A114D077AJ05002_Dft    14     17        TP    9  176   23  193)
# --------
# TP
# A114D077AJ08001_Dft
# data(filename='A114D077AJ08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1514  A114D077AJ08001_Dft    20     30        TP    4  177   24  207)
# --------
# PP
# A114D077AK03001_Dft
# data(filename='A114D077AK03001_Dft', object=                filename width height className xmin ymin xmax ymax
# 504  A114D077AK03001_Dft     9     12        PP   32  471   41  483)
# --------
# TP
# A114D077AK06001_Dft
# data(filename='A114D077AK06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1515  A114D077AK06001_Dft    14     22        TP  157  487  171  509)
# --------
# I_R
# A114D077AL05001_Dft
# data(filename='A114D077AL05001_Dft', object=              filename width height className xmin ymin xmax ymax
# 1  A114D077AL05001_Dft     6     20       I_R   35  454   41  474)
# --------
# TP
# A114D077AL08002_Dft
# data(filename='A114D077AL08002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1516  A114D077AL08002_Dft     5      7        TP   28  458   33  465)
# --------
# TP
# A114D077AL08005_Dft
# data(filename='A114D077AL08005_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1517  A114D077AL08005_Dft    37     19        TP   26  462   63  481)
# --------
# PP
# A114E00NAN01001_Dft
# data(filename='A114E00NAN01001_Dft', object=                filename width height className xmin ymin xmax ymax
# 505  A114E00NAN01001_Dft    58     56        PP    8  175   66  231)
# --------
# TP
# A114E00NAN07002_Dft
# data(filename='A114E00NAN07002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1518  A114E00NAN07002_Dft    39     41        TP   18  439   57  480)
# --------
# I_R
# A114E00NAN08002_Dft
# data(filename='A114E00NAN08002_Dft', object=              filename width height className xmin ymin xmax ymax
# 2  A114E00NAN08002_Dft     2      5       I_R   36  473   38  478)
# --------
# TP
# A114E02LCE03004_Dft
# data(filename='A114E02LCE03004_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1519  A114E02LCE03004_Dft    17     15        TP    7  451   24  466)
# --------
# TP
# A114E036CA06001_Dft
# data(filename='A114E036CA06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1520  A114E036CA06001_Dft    25     24        TP    0  474   25  498)
# --------
# I_R
# A114E036CA07001_Dft
# data(filename='A114E036CA07001_Dft', object=              filename width height className xmin ymin xmax ymax
# 3  A114E036CA07001_Dft     5      8       I_R   34  470   39  478)
# --------
# TP
# A114E037CB04001_Dft
# data(filename='A114E037CB04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1521  A114E037CB04001_Dft    10     13        TP   19  464   29  477)
# --------
# Udev
# A114E03EAT01001_Dft
# data(filename='A114E03EAT01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2003  A114E03EAT01001_Dft    23     23      Udev   33  412   56  435)
# --------
# PP
# A114E03EAT01002_Dft
# data(filename='A114E03EAT01002_Dft', object=                filename width height className xmin ymin xmax ymax
# 506  A114E03EAT01002_Dft    20     17        PP   13  248   33  265)
# --------
# TP
# A114E03EAT05001_Dft
# data(filename='A114E03EAT05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1522  A114E03EAT05001_Dft     9     12        TP    2  397   11  409)
# --------
# PP
# A114E06UBQ03001_Dft
# data(filename='A114E06UBQ03001_Dft', object=                filename width height className xmin ymin xmax ymax
# 507  A114E06UBQ03001_Dft    45     17        PP   63  404  108  421)
# --------
# TP
# A114E06UBQ05004_Dft
# data(filename='A114E06UBQ05004_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1523  A114E06UBQ05004_Dft    15      8        TP   23  453   38  461)
# --------
# TP
# A114E06UBQ07003_Dft
# data(filename='A114E06UBQ07003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1524  A114E06UBQ07003_Dft    15     12        TP    7  471   22  483)
# --------
# TP
# A114E06UBQ07004_Dft
# data(filename='A114E06UBQ07004_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1525  A114E06UBQ07004_Dft    33     39        TP    4  196   37  235)
# --------
# TP
# A114E06UBQ07005_Dft
# data(filename='A114E06UBQ07005_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1526  A114E06UBQ07005_Dft    39     47        TP    8  245   47  292)
# --------
# TP
# A114E06UBQ08001_Dft
# data(filename='A114E06UBQ08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1527  A114E06UBQ08001_Dft    11     11        TP   20  461   31  472)
# --------
# TP
# A114E07VCH03001_Dft
# data(filename='A114E07VCH03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1528  A114E07VCH03001_Dft    15     11        TP    9  120   24  131)
# --------
# PP_Pb
# A114F00LCE04001_Dft
# data(filename='A114F00LCE04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1001  A114F00LCE04001_Dft     3      5     PP_Pb  160  266  163  271)
# --------
# TP
# A114F00MAG02002_Dft
# data(filename='A114F00MAG02002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1529  A114F00MAG02002_Dft     6     10        TP   17  456   23  466)
# --------
# I_R
# A114F00MAG06001_Dft
# data(filename='A114F00MAG06001_Dft', object=              filename width height className xmin ymin xmax ymax
# 4  A114F00MAG06001_Dft     6      7       I_R   32  470   38  477)
# --------
# TP
# A114F013CC01002_Dft
# data(filename='A114F013CC01002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1530  A114F013CC01002_Dft     6      9        TP   35  464   41  473)
# --------
# Udev
# A114F013CC06001_Dft
# data(filename='A114F013CC06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2004  A114F013CC06001_Dft    21     21      Udev   33  413   54  434)
# --------
# TP
# A114F01HCA01001_Dft
# data(filename='A114F01HCA01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1531  A114F01HCA01001_Dft    10     12        TP   35  455   45  467)
# --------
# TP
# A114F01HCA07001_Dft
# data(filename='A114F01HCA07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1532  A114F01HCA07001_Dft    15     15        TP  159  172  174  187)
# --------
# TP
# A114F01HCC03001_Dft
# data(filename='A114F01HCC03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1533  A114F01HCC03001_Dft    12      9        TP   20  457   32  466)
# --------
# TP
# A114F021AU03001_Dft
# data(filename='A114F021AU03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1534  A114F021AU03001_Dft    16     16        TP    6  310   22  326)
# --------
# TP
# A114F021AU05001_Dft
# data(filename='A114F021AU05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1535  A114F021AU05001_Dft    15     15        TP   16  463   31  478)
# --------
# TP
# A114F021AU06003_Dft
# data(filename='A114F021AU06003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1536  A114F021AU06003_Dft     8      7        TP  163  223  171  230)
# --------
# TP
# A114F038AU06001_Dft
# data(filename='A114F038AU06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1537  A114F038AU06001_Dft    18     13        TP    9   15   27   28)
# --------
# TP
# A114F048AE01002_Dft
# data(filename='A114F048AE01002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1538  A114F048AE01002_Dft    10     21        TP  161  482  171  503)
# --------
# PP
# A114F048AE01003_Dft
# data(filename='A114F048AE01003_Dft', object=                filename width height className xmin ymin xmax ymax
# 508  A114F048AE01003_Dft    27     36        PP    4  448   31  484)
# --------
# Udev
# A114F048AE05001_Dft
# data(filename='A114F048AE05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2005  A114F048AE05001_Dft     4      6      Udev   92  415   96  421)
# --------
# TP
# A114F048AE07004_Dft
# data(filename='A114F048AE07004_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1539  A114F048AE07004_Dft    27     29        TP    5  461   32  490)
# --------
# PP
# A114F048AE08002_Dft
# data(filename='A114F048AE08002_Dft', object=                filename width height className xmin ymin xmax ymax
# 509  A114F048AE08002_Dft    21     18        PP    3   42   24   60)
# --------
# PP
# A114F05BAB01006_Dft
# data(filename='A114F05BAB01006_Dft', object=                filename width height className xmin ymin xmax ymax
# 510  A114F05BAB01006_Dft    39     53        PP   13  214   52  267)
# --------
# PP
# A114F061AE06002_Dft
# data(filename='A114F061AE06002_Dft', object=                filename width height className xmin ymin xmax ymax
# 511  A114F061AE06002_Dft     7     10        PP  146  382  153  392)
# --------
# PP
# A114F061AE08002_Dft
# data(filename='A114F061AE08002_Dft', object=                filename width height className xmin ymin xmax ymax
# 512  A114F061AE08002_Dft     8     21        PP   16  211   24  232)
# --------
# TP
# A114F07XAV03001_Dft
# data(filename='A114F07XAV03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1540  A114F07XAV03001_Dft    21     17        TP   18  462   39  479)
# --------
# Udev
# A114F07XAV05001_Dft
# data(filename='A114F07XAV05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2006  A114F07XAV05001_Dft     9     12      Udev   67  409   76  421)
# --------
# Udev
# A114F07XAV06001_Dft
# data(filename='A114F07XAV06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2007  A114F07XAV06001_Dft    17     10      Udev   99  413  116  423)
# --------
# TP
# A114F07XAV06002_Dft
# data(filename='A114F07XAV06002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1541  A114F07XAV06002_Dft    10     18        TP   16  449   26  467)
# --------
# TP
# A114F07YBH07001_Dft
# data(filename='A114F07YBH07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1542  A114F07YBH07001_Dft    11      8        TP    6   77   17   85)
# --------
# I_R
# A114F07YBH08001_Dft
# data(filename='A114F07YBH08001_Dft', object=              filename width height className xmin ymin xmax ymax
# 5  A114F07YBH08001_Dft    44     70       I_R   10  304   54  374)
# --------
# TP
# A114F07YBH08003_Dft
# data(filename='A114F07YBH08003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1543  A114F07YBH08003_Dft    10     20        TP   12   70   22   90)
# --------
# I_R
# A114F08LBF05001_Dft
# data(filename='A114F08LBF05001_Dft', object=              filename width height className xmin ymin xmax ymax
# 6  A114F08LBF05001_Dft     7     14       I_R   33  465   40  479)
# --------
# PP
# A114F08LBF05004_Dft
# data(filename='A114F08LBF05004_Dft', object=                filename width height className xmin ymin xmax ymax
# 513  A114F08LBF05004_Dft    25     26        PP    6  477   31  503)
# --------
# PP
# A114F08LBF05005_Dft
# data(filename='A114F08LBF05005_Dft', object=                filename width height className xmin ymin xmax ymax
# 514  A114F08LBF05005_Dft    35     39        PP   20  454   55  493)
# --------
# PP_Pb
# A114F08LBF07001_Dft
# data(filename='A114F08LBF07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1002  A114F08LBF07001_Dft     9      8     PP_Pb   20  394   29  402)
# --------
# PP
# A114F08LBF07003_Dft
# data(filename='A114F08LBF07003_Dft', object=                filename width height className xmin ymin xmax ymax
# 515  A114F08LBF07003_Dft    42     37        PP   19   31   61   68)
# --------
# TP
# A114G008AF01002_Dft
# data(filename='A114G008AF01002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1544  A114G008AF01002_Dft    14     13        TP   10  459   24  472)
# --------
# TP
# A114G00GAQ05003_Dft
# data(filename='A114G00GAQ05003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1545  A114G00GAQ05003_Dft    17     15        TP    9  190   26  205)
# --------
# PP
# A114G01ABP08001_Dft
# data(filename='A114G01ABP08001_Dft', object=                filename width height className xmin ymin xmax ymax
# 516  A114G01ABP08001_Dft    43     42        PP    7  429   50  471)
# --------
# TP
# A114G01WBF08001_Dft
# data(filename='A114G01WBF08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1546  A114G01WBF08001_Dft    16     15        TP    7   49   23   64)
# --------
# PP
# A114G02HBX03001_Dft
# data(filename='A114G02HBX03001_Dft', object=                filename width height className xmin ymin xmax ymax
# 517  A114G02HBX03001_Dft    53     37        PP    1  208   54  245)
# --------
# TP
# A114G02JCG01002_Dft
# data(filename='A114G02JCG01002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1547  A114G02JCG01002_Dft     6      7        TP   31  447   37  454)
# --------
# TP
# A114G02JCG03003_Dft
# data(filename='A114G02JCG03003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1548  A114G02JCG03003_Dft    17     17        TP   18  456   35  473)
# --------
# TP
# A114G02MBA03001_Dft
# data(filename='A114G02MBA03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1549  A114G02MBA03001_Dft    14      9        TP    5  244   19  253)
# --------
# TP
# A114G03GAN08002_Dft
# data(filename='A114G03GAN08002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1550  A114G03GAN08002_Dft    16     22        TP   32  444   48  466)
# --------
# TP
# A114G03HBK05001_Dft
# data(filename='A114G03HBK05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1551  A114G03HBK05001_Dft     7     14        TP   16  458   23  472)
# --------
# I_R
# A114G041AN02001_Dft
# data(filename='A114G041AN02001_Dft', object=              filename width height className xmin ymin xmax ymax
# 7  A114G041AN02001_Dft    23     18       I_R   19  456   42  474)
# --------
# PP
# A114G041AN08001_Dft
# data(filename='A114G041AN08001_Dft', object=                filename width height className xmin ymin xmax ymax
# 518  A114G041AN08001_Dft    35     63        PP    1  370   36  433)
# --------
# TP
# A114G058BU06001_Dft
# data(filename='A114G058BU06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1552  A114G058BU06001_Dft     7     11        TP   18  466   25  477)
# --------
# TP
# A114G05MBK08001_Dft
# data(filename='A114G05MBK08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1553  A114G05MBK08001_Dft     6     10        TP   35  460   41  470)
# --------
# TP
# A114G05MBK08003_Dft
# data(filename='A114G05MBK08003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1554  A114G05MBK08003_Dft     9      9        TP  164    5  173   14)
# --------
# TP
# A114G05TAJ07001_Dft
# data(filename='A114G05TAJ07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1555  A114G05TAJ07001_Dft    13     14        TP  165  216  178  230)
# --------
# TP
# A114G06CAH07003_Dft
# data(filename='A114G06CAH07003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1556  A114G06CAH07003_Dft     6     17        TP    0  340    6  357)
# --------
# TP
# A114G06HAF02001_Dft
# data(filename='A114G06HAF02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1557  A114G06HAF02001_Dft     4      5        TP   11  471   15  476)
# --------
# TP
# A114G06HAF04001_Dft
# data(filename='A114G06HAF04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1558  A114G06HAF04001_Dft    14     14        TP   19  464   33  478)
# --------
# TP
# A114G06HAX02001_Dft
# data(filename='A114G06HAX02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1559  A114G06HAX02001_Dft     6     17        TP   28  457   34  474)
# --------
# TP
# A114G06HAX04001_Dft
# data(filename='A114G06HAX04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1560  A114G06HAX04001_Dft    16     11        TP    7  336   23  347)
# --------
# PP_Pb
# A114G06HAX08001_Dft
# data(filename='A114G06HAX08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1003  A114G06HAX08001_Dft    19     20     PP_Pb   20  309   39  329)
# --------
# TP
# A114G06HBH02001_Dft
# data(filename='A114G06HBH02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1561  A114G06HBH02001_Dft    10     14        TP    4  457   14  471)
# --------
# TP
# A114G06HBH02002_Dft
# data(filename='A114G06HBH02002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1562  A114G06HBH02002_Dft    16     19        TP    8  459   24  478)
# --------
# PP_Pb
# A114H009AP08001_Dft
# data(filename='A114H009AP08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1004  A114H009AP08001_Dft     5      6     PP_Pb  158  134  163  140)
# --------
# PP
# A114H00QBL07002_Dft
# data(filename='A114H00QBL07002_Dft', object=                filename width height className xmin ymin xmax ymax
# 519  A114H00QBL07002_Dft    27     24        PP    3    1   30   25)
# --------
# TP
# A114H00QCB01001_Dft
# data(filename='A114H00QCB01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1563  A114H00QCB01001_Dft    16     19        TP    6  321   22  340)
# --------
# TP
# A114H00QCB03001_Dft
# data(filename='A114H00QCB03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1564  A114H00QCB03001_Dft     6      8        TP   20  465   26  473)
# --------
# TP
# A114H00QCB04001_Dft
# data(filename='A114H00QCB04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1565  A114H00QCB04001_Dft    15     13        TP    3  316   18  329)
# --------
# TP
# A114H00QCB05002_Dft
# data(filename='A114H00QCB05002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1566  A114H00QCB05002_Dft     8     12        TP    4  392   12  404)
# --------
# TP
# A114H00QCB07003_Dft
# data(filename='A114H00QCB07003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1567  A114H00QCB07003_Dft     9     14        TP   13   89   22  103)
# --------
# TP
# A114H00QCD02002_Dft
# data(filename='A114H00QCD02002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1568  A114H00QCD02002_Dft    17     12        TP    7  228   24  240)
# --------
# TP
# A114H00QCD05001_Dft
# data(filename='A114H00QCD05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1569  A114H00QCD05001_Dft    15     18        TP    2  394   17  412)
# --------
# PP
# A114H01DBC08001_Dft
# data(filename='A114H01DBC08001_Dft', object=                filename width height className xmin ymin xmax ymax
# 520  A114H01DBC08001_Dft    19     23        PP   28  459   47  482)
# --------
# PP_Pb
# A114H029AX08001_Dft
# data(filename='A114H029AX08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1005  A114H029AX08001_Dft     6      8     PP_Pb  158   74  164   82)
# --------
# TP
# A114H02UAE05001_Dft
# data(filename='A114H02UAE05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1570  A114H02UAE05001_Dft    24     27        TP    8  436   32  463)
# --------
# I_R
# A114H02UCF06002_Dft
# data(filename='A114H02UCF06002_Dft', object=              filename width height className xmin ymin xmax ymax
# 8  A114H02UCF06002_Dft    23     23       I_R   19  457   42  480)
# --------
# TP
# A114H02UCJ07001_Dft
# data(filename='A114H02UCJ07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1571  A114H02UCJ07001_Dft     6      6        TP   23  465   29  471)
# --------
# Udev
# A114H02UCJ08001_Dft
# data(filename='A114H02UCJ08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2008  A114H02UCJ08001_Dft    20     19      Udev   35  424   55  443)
# --------
# TP
# A114H03GAB03001_Dft
# data(filename='A114H03GAB03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1572  A114H03GAB03001_Dft    21     25        TP    3  328   24  353)
# --------
# TP
# A114H03GAB05001_Dft
# data(filename='A114H03GAB05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1573  A114H03GAB05001_Dft    25     68        TP   11  128   36  196)
# --------
# TP
# A114H03GAT07001_Dft
# data(filename='A114H03GAT07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1574  A114H03GAT07001_Dft     6      9        TP   11  218   17  227)
# --------
# TP
# A114H03GBB04001_Dft
# data(filename='A114H03GBB04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1575  A114H03GBB04001_Dft    13     24        TP   10  178   23  202)
# --------
# PP
# A114H03GBB05001_Dft
# data(filename='A114H03GBB05001_Dft', object=                filename width height className xmin ymin xmax ymax
# 521  A114H03GBB05001_Dft    13      8        PP   12  450   25  458)
# --------
# TP
# A114H03GBB07001_Dft
# data(filename='A114H03GBB07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1576  A114H03GBB07001_Dft     7     13        TP   35  464   42  477)
# --------
# TP
# A114H03GBB07002_Dft
# data(filename='A114H03GBB07002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1577  A114H03GBB07002_Dft    13     23        TP    2  386   15  409)
# --------
# TP
# A114H03WAU01001_Dft
# data(filename='A114H03WAU01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1578  A114H03WAU01001_Dft    29     30        TP   19  455   48  485)
# --------
# PP
# A114H03WAU02004_Dft
# data(filename='A114H03WAU02004_Dft', object=                filename width height className xmin ymin xmax ymax
# 522  A114H03WAU02004_Dft    74     73        PP   36  408  110  481)
# --------
# I_R
# A114H03WAU02007_Dft
# data(filename='A114H03WAU02007_Dft', object=              filename width height className xmin ymin xmax ymax
# 9  A114H03WAU02007_Dft     8     12       I_R   31  454   39  466)
# --------
# TP
# A114H03WAU06002_Dft
# data(filename='A114H03WAU06002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1579  A114H03WAU06002_Dft    12     14        TP  154  420  166  434)
# --------
# TP
# A114H03WBC01002_Dft
# data(filename='A114H03WBC01002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1580  A114H03WBC01002_Dft    33     30        TP   18  451   51  481)
# --------
# PP
# A114H03WBF04001_Dft
# data(filename='A114H03WBF04001_Dft', object=                filename width height className xmin ymin xmax ymax
# 523  A114H03WBF04001_Dft    24     27        PP  146  391  170  418)
# --------
# TP
# A114H03WBG02001_Dft
# data(filename='A114H03WBG02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1581  A114H03WBG02001_Dft    11     16        TP   37  463   48  479)
# --------
# PP
# A114H042BM08002_Dft
# data(filename='A114H042BM08002_Dft', object=                filename width height className xmin ymin xmax ymax
# 524  A114H042BM08002_Dft    32     71        PP    0  384   32  455)
# --------
# TP
# A114H042BN01001_Dft
# data(filename='A114H042BN01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1582  A114H042BN01001_Dft    21     26        TP    2  210   23  236)
# --------
# TP
# A114H042BN02002_Dft
# data(filename='A114H042BN02002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1583  A114H042BN02002_Dft    17     15        TP    6  426   23  441)
# --------
# TP
# A114H042BQ02001_Dft
# data(filename='A114H042BQ02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1584  A114H042BQ02001_Dft    53     45        TP    3  408   56  453)
# --------
# TP
# A114H042BS02001_Dft
# data(filename='A114H042BS02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1585  A114H042BS02001_Dft     8      8        TP   18  466   26  474)
# --------
# TP
# A114H042BS02002_Dft
# data(filename='A114H042BS02002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1586  A114H042BS02002_Dft    14     15        TP    3  189   17  204)
# --------
# TP
# A114H042BS05002_Dft
# data(filename='A114H042BS05002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1587  A114H042BS05002_Dft    29     36        TP   17  448   46  484)
# --------
# TP
# A114H042BV02001_Dft
# data(filename='A114H042BV02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1588  A114H042BV02001_Dft     8      5        TP   41  458   49  463)
# --------
# PP
# A114H042BV06002_Dft
# data(filename='A114H042BV06002_Dft', object=                filename width height className xmin ymin xmax ymax
# 525  A114H042BV06002_Dft    12     11        PP   66  410   78  421)
# --------
# Udev
# A114H042BV08001_Dft
# data(filename='A114H042BV08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2009  A114H042BV08001_Dft     5      5      Udev   61  426   66  431)
# --------
# TP
# A114H042BW01002_Dft
# data(filename='A114H042BW01002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1589  A114H042BW01002_Dft    11     11        TP  161  134  172  145)
# --------
# TP
# A114H042BW03005_Dft
# data(filename='A114H042BW03005_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1590  A114H042BW03005_Dft    10     12        TP  160  152  170  164)
# --------
# TP
# A114H042BW04001_Dft
# data(filename='A114H042BW04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1591  A114H042BW04001_Dft    10     11        TP   34  455   44  466)
# --------
# TP
# A114H042BW06001_Dft
# data(filename='A114H042BW06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1592  A114H042BW06001_Dft    18     13        TP    7  308   25  321)
# --------
# TP
# A114H042BW06002_Dft
# data(filename='A114H042BW06002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1593  A114H042BW06002_Dft    10      8        TP   17  454   27  462)
# --------
# TP
# A114H042BW06003_Dft
# data(filename='A114H042BW06003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1594  A114H042BW06003_Dft    16     15        TP    8  340   24  355)
# --------
# I_R
# A114H042BW07001_Dft
# data(filename='A114H042BW07001_Dft', object=               filename width height className xmin ymin xmax ymax
# 10  A114H042BW07001_Dft     7     22       I_R   19  457   26  479)
# --------
# PP
# A114H042BY05002_Dft
# data(filename='A114H042BY05002_Dft', object=                filename width height className xmin ymin xmax ymax
# 526  A114H042BY05002_Dft    41     56        PP   28  263   69  319)
# --------
# TP
# A114H042CB02002_Dft
# data(filename='A114H042CB02002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1595  A114H042CB02002_Dft    12     20        TP   18  460   30  480)
# --------
# PP_Pb
# A114H042CB03001_Dft
# data(filename='A114H042CB03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1006  A114H042CB03001_Dft     5      9     PP_Pb   22   10   27   19)
# --------
# Udev
# A114H042CB05001_Dft
# data(filename='A114H042CB05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2010  A114H042CB05001_Dft    22     21      Udev   32  412   54  433)
# --------
# TP
# A114H042CC04001_Dft
# data(filename='A114H042CC04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1596  A114H042CC04001_Dft     8     11        TP   17  461   25  472)
# --------
# TP
# A114H042CC06003_Dft
# data(filename='A114H042CC06003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1597  A114H042CC06003_Dft    18     18        TP  160  502  178  520)
# --------
# TP
# A114H042CD01001_Dft
# data(filename='A114H042CD01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1598  A114H042CD01001_Dft    17     19        TP    7  459   24  478)
# --------
# TP
# A114H042CD01002_Dft
# data(filename='A114H042CD01002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1599  A114H042CD01002_Dft    17     14        TP    2  355   19  369)
# --------
# TP
# A114H042CK03001_Dft
# data(filename='A114H042CK03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1600  A114H042CK03001_Dft    16     15        TP    7  133   23  148)
# --------
# PP_Pb
# A114H043BC04001_Dft
# data(filename='A114H043BC04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1007  A114H043BC04001_Dft     7      8     PP_Pb   15  250   22  258)
# --------
# PP
# A114H043BC04003_Dft
# data(filename='A114H043BC04003_Dft', object=                filename width height className xmin ymin xmax ymax
# 527  A114H043BC04003_Dft    18     20        PP   44  469   62  489)
# --------
# PP
# A114H043BC06001_Dft
# data(filename='A114H043BC06001_Dft', object=                filename width height className xmin ymin xmax ymax
# 528  A114H043BC06001_Dft    36     34        PP   97  297  133  331)
# --------
# TP
# A114H043BC07001_Dft
# data(filename='A114H043BC07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1601  A114H043BC07001_Dft    16     20        TP   32  478   48  498)
# --------
# PP
# A114H043BD03001_Dft
# data(filename='A114H043BD03001_Dft', object=                filename width height className xmin ymin xmax ymax
# 529  A114H043BD03001_Dft    26     27        PP   64  392   90  419)
# --------
# TP
# A114H043BD08002_Dft
# data(filename='A114H043BD08002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1602  A114H043BD08002_Dft    18     17        TP    5   95   23  112)
# --------
# TP
# A114H043BM06001_Dft
# data(filename='A114H043BM06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1603  A114H043BM06001_Dft    12     10        TP   33  456   45  466)
# --------
# TP
# A114H043BQ01005_Dft
# data(filename='A114H043BQ01005_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1604  A114H043BQ01005_Dft    15     17        TP    8  335   23  352)
# --------
# TP
# A114H043BT05001_Dft
# data(filename='A114H043BT05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1605  A114H043BT05001_Dft    12     10        TP   31  472   43  482)
# --------
# PP
# A114H043BT08001_Dft
# data(filename='A114H043BT08001_Dft', object=                filename width height className xmin ymin xmax ymax
# 530  A114H043BT08001_Dft    30     34        PP   14  239   44  273)
# --------
# TP
# A114H043BV02002_Dft
# data(filename='A114H043BV02002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1606  A114H043BV02002_Dft    19     12        TP   11  473   30  485)
# --------
# TP
# A114H043BV03001_Dft
# data(filename='A114H043BV03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1607  A114H043BV03001_Dft    11     13        TP   30  467   41  480)
# --------
# TP
# A114H043BY03001_Dft
# data(filename='A114H043BY03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1608  A114H043BY03001_Dft    17     28        TP    6   88   23  116)
# --------
# I_R
# A114H043BY05002_Dft
# data(filename='A114H043BY05002_Dft', object=               filename width height className xmin ymin xmax ymax
# 11  A114H043BY05002_Dft    18     28       I_R   14  414   32  442)
# --------
# PP
# A114H043BY06001_Dft
# data(filename='A114H043BY06001_Dft', object=                filename width height className xmin ymin xmax ymax
# 531  A114H043BY06001_Dft   118    119        PP   30  320  148  439)
# --------
# TP
# A114H043BY06002_Dft
# data(filename='A114H043BY06002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1609  A114H043BY06002_Dft    10     12        TP  159  307  169  319)
# --------
# TP
# A114H043BY08001_Dft
# data(filename='A114H043BY08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1610  A114H043BY08001_Dft    16     22        TP   13  212   29  234)
# --------
# TP
# A114H043BY08002_Dft
# data(filename='A114H043BY08002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1611  A114H043BY08002_Dft    15     10        TP   24  394   39  404)
# --------
# Udev
# A114H04AAC03001_Dft
# data(filename='A114H04AAC03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2011  A114H04AAC03001_Dft     9     10      Udev   18  471   27  481)
# --------
# TP
# A114H04AAC07001_Dft
# data(filename='A114H04AAC07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1612  A114H04AAC07001_Dft    15     12        TP   11  467   26  479)
# --------
# TP
# A114H04DCA06002_Dft
# data(filename='A114H04DCA06002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1613  A114H04DCA06002_Dft    26     32        TP   27  414   53  446)
# --------
# PP
# A114H04DCB01003_Dft
# data(filename='A114H04DCB01003_Dft', object=                filename width height className xmin ymin xmax ymax
# 532  A114H04DCB01003_Dft     4     12        PP   24  435   28  447)
# --------
# TP
# A114H04DCB01004_Dft
# data(filename='A114H04DCB01004_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1614  A114H04DCB01004_Dft    11      9        TP  163  269  174  278)
# --------
# TP
# A114H04PAU03001_Dft
# data(filename='A114H04PAU03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1615  A114H04PAU03001_Dft     6      6        TP   14  454   20  460)
# --------
# I_R
# A114H04PAU04001_Dft
# data(filename='A114H04PAU04001_Dft', object=               filename width height className xmin ymin xmax ymax
# 12  A114H04PAU04001_Dft     7     21       I_R   18  456   25  477)
# --------
# TP
# A114H04PAU08001_Dft
# data(filename='A114H04PAU08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1616  A114H04PAU08001_Dft     6      7        TP   20  460   26  467)
# --------
# I_R
# A114H04PAW01001_Dft
# data(filename='A114H04PAW01001_Dft', object=               filename width height className xmin ymin xmax ymax
# 13  A114H04PAW01001_Dft    21     23       I_R   18  454   39  477)
# --------
# I_R
# A114H04PAW02001_Dft
# data(filename='A114H04PAW02001_Dft', object=               filename width height className xmin ymin xmax ymax
# 14  A114H04PAW02001_Dft    14     17       I_R   35  414   49  431)
# --------
# PP
# A114H04PAW07001_Dft
# data(filename='A114H04PAW07001_Dft', object=                filename width height className xmin ymin xmax ymax
# 533  A114H04PAW07001_Dft    31     26        PP   14  450   45  476)
# --------
# TP
# A114H04PBX02002_Dft
# data(filename='A114H04PBX02002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1617  A114H04PBX02002_Dft    11      8        TP   20  457   31  465)
# --------
# PP
# A114H04PBX06001_Dft
# data(filename='A114H04PBX06001_Dft', object=                filename width height className xmin ymin xmax ymax
# 534  A114H04PBX06001_Dft     9     29        PP   15  236   24  265)
# --------
# TP
# A114H04PCA05001_Dft
# data(filename='A114H04PCA05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1618  A114H04PCA05001_Dft    11     13        TP   16  465   27  478)
# --------
# TP
# A114H04PCA06001_Dft
# data(filename='A114H04PCA06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1619  A114H04PCA06001_Dft     6      8        TP   43  476   49  484)
# --------
# PP
# A114H04PCA06002_Dft
# data(filename='A114H04PCA06002_Dft', object=                filename width height className xmin ymin xmax ymax
# 535  A114H04PCA06002_Dft     7     19        PP    0  347    7  366)
# --------
# TP
# A114H04PCE04001_Dft
# data(filename='A114H04PCE04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1620  A114H04PCE04001_Dft     9      9        TP   16  454   25  463)
# --------
# Udev
# A114H04PCE07001_Dft
# data(filename='A114H04PCE07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2012  A114H04PCE07001_Dft     5      4      Udev  149  404  154  408)
# --------
# I_R
# A114H04PCG06001_Dft
# data(filename='A114H04PCG06001_Dft', object=               filename width height className xmin ymin xmax ymax
# 15  A114H04PCG06001_Dft     6     12       I_R   35  464   41  476)
# --------
# I_R
# A114H04PCG06002_Dft
# data(filename='A114H04PCG06002_Dft', object=               filename width height className xmin ymin xmax ymax
# 16  A114H04PCG06002_Dft     4     11       I_R   36  465   40  476)
# --------
# I_R
# A114H04PCG06003_Dft
# data(filename='A114H04PCG06003_Dft', object=               filename width height className xmin ymin xmax ymax
# 17  A114H04PCG06003_Dft     5     11       I_R   35  464   40  475)
# --------
# TP
# A114H04WBH03002_Dft
# data(filename='A114H04WBH03002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1621  A114H04WBH03002_Dft    13     20        TP    1   16   14   36)
# --------
# TP
# A114H04XBQ03001_Dft
# data(filename='A114H04XBQ03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1622  A114H04XBQ03001_Dft     7      7        TP   19  472   26  479)
# --------
# TP
# A114H04YAQ01001_Dft
# data(filename='A114H04YAQ01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1623  A114H04YAQ01001_Dft    21     24        TP  153  200  174  224)
# --------
# PP
# A114H04YAU02001_Dft
# data(filename='A114H04YAU02001_Dft', object=                filename width height className xmin ymin xmax ymax
# 536  A114H04YAU02001_Dft    22    167        PP    1  234   23  401)
# --------
# TP
# A114H050AF01002_Dft
# data(filename='A114H050AF01002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1624  A114H050AF01002_Dft    32     23        TP  180  146  212  169)
# --------
# I_R
# A114H050BJ02003_Dft
# data(filename='A114H050BJ02003_Dft', object=               filename width height className xmin ymin xmax ymax
# 18  A114H050BJ02003_Dft    16     22       I_R   35  454   51  476)
# --------
# TP
# A114H050BJ04002_Dft
# data(filename='A114H050BJ04002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1625  A114H050BJ04002_Dft    15     30        TP    6   68   21   98)
# --------
# TP
# A114H050BL07002_Dft
# data(filename='A114H050BL07002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1626  A114H050BL07002_Dft    15     16        TP    8  297   23  313)
# --------
# TP
# A114H051AA03001_Dft
# data(filename='A114H051AA03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1627  A114H051AA03001_Dft    13     14        TP    4  289   17  303)
# --------
# TP
# A114H051AA08001_Dft
# data(filename='A114H051AA08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1628  A114H051AA08001_Dft     9     12        TP    3  391   12  403)
# --------
# TP
# A114H051AK01001_Dft
# data(filename='A114H051AK01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1629  A114H051AK01001_Dft     3     10        TP   43  467   46  477)
# --------
# TP
# A114H051AM03001_Dft
# data(filename='A114H051AM03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1630  A114H051AM03001_Dft     9     12        TP    2  465   11  477)
# --------
# PP
# A114H051AN04001_Dft
# data(filename='A114H051AN04001_Dft', object=                filename width height className xmin ymin xmax ymax
# 537  A114H051AN04001_Dft     0      0        PP    0    0    0    0)
# --------
# PP
# A114H051AR03006_Dft
# data(filename='A114H051AR03006_Dft', object=                filename width height className xmin ymin xmax ymax
# 538  A114H051AR03006_Dft    30     22        PP   15  364   45  386)
# --------
# TP
# A114H051AR04003_Dft
# data(filename='A114H051AR04003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1631  A114H051AR04003_Dft    20     17        TP  141  413  161  430)
# --------
# TP
# A114H051AR07001_Dft
# data(filename='A114H051AR07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1632  A114H051AR07001_Dft     9      9        TP   35  473   44  482)
# --------
# TP
# A114H051AT02003_Dft
# data(filename='A114H051AT02003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1633  A114H051AT02003_Dft     6      7        TP   18  461   24  468)
# --------
# TP
# A114H051AT04001_Dft
# data(filename='A114H051AT04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1634  A114H051AT04001_Dft    14     10        TP    6  202   20  212)
# --------
# TP
# A114H051AT05001_Dft
# data(filename='A114H051AT05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1635  A114H051AT05001_Dft    16     14        TP   12  426   28  440)
# --------
# TP
# A114H051AU03002_Dft
# data(filename='A114H051AU03002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1636  A114H051AU03002_Dft    17     12        TP    8  378   25  390)
# --------
# TP
# A114H051AU03003_Dft
# data(filename='A114H051AU03003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1637  A114H051AU03003_Dft    10     13        TP  160  256  170  269)
# --------
# Udev
# A114H051AU07001_Dft
# data(filename='A114H051AU07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2013  A114H051AU07001_Dft    55     36      Udev   98  387  153  423)
# --------
# TP
# A114H051AV01001_Dft
# data(filename='A114H051AV01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1638  A114H051AV01001_Dft     9      9        TP   34  462   43  471)
# --------
# I_R
# A114H051AV04001_Dft
# data(filename='A114H051AV04001_Dft', object=               filename width height className xmin ymin xmax ymax
# 19  A114H051AV04001_Dft     9      9       I_R   33  455   42  464)
# --------
# TP
# A114H051AV04005_Dft
# data(filename='A114H051AV04005_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1639  A114H051AV04005_Dft    10      9        TP    5  398   15  407)
# --------
# TP
# A114H051AV04006_Dft
# data(filename='A114H051AV04006_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1640  A114H051AV04006_Dft    11     13        TP   13  303   24  316)
# --------
# PP
# A114H051AV05002_Dft
# data(filename='A114H051AV05002_Dft', object=                filename width height className xmin ymin xmax ymax
# 539  A114H051AV05002_Dft    35     43        PP   15  279   50  322)
# --------
# Udev
# A114H051AX01001_Dft
# data(filename='A114H051AX01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2014  A114H051AX01001_Dft    30     39      Udev   15  457   45  496)
# --------
# TP
# A114H051AX02003_Dft
# data(filename='A114H051AX02003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1641  A114H051AX02003_Dft    12     19        TP   13  332   25  351)
# --------
# TP
# A114H051AY02001_Dft
# data(filename='A114H051AY02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1642  A114H051AY02001_Dft    16     14        TP   12  447   28  461)
# --------
# Udev
# A114H051BM07001_Dft
# data(filename='A114H051BM07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2015  A114H051BM07001_Dft    13      8      Udev  101  415  114  423)
# --------
# TP
# A114H051BT03001_Dft
# data(filename='A114H051BT03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# ...
# 1450  A115S056CB02001_Dft    31     29     PP_Pb   16  105   47  134)
# --------
# Udev
# A115S057AK04001_Dft
# data(filename='A115S057AK04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2479  A115S057AK04001_Dft    12      6      Udev  120  509  132  515)
# --------
# Udev
# A115S057AQ02001_Dft
# data(filename='A115S057AQ02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2480  A115S057AQ02001_Dft     5     20      Udev    3  412    8  432)
# --------
# PP_Pb
# A115S057BX04001_Dft
# data(filename='A115S057BX04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1451  A115S057BX04001_Dft     2      2     PP_Pb   14  496   16  498)
# --------
# PP_Pb
# A115S07VBL01002_Dft
# data(filename='A115S07VBL01002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1452  A115S07VBL01002_Dft     5     19     PP_Pb   17   55   22   74)
# --------
# PP_Pb
# A115S08RAM02001_Dft
# data(filename='A115S08RAM02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1453  A115S08RAM02001_Dft     8      8     PP_Pb   17   53   25   61)
# --------
# PP_Pb
# A115S08RCD02001_Dft
# data(filename='A115S08RCD02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1454  A115S08RCD02001_Dft    16     18     PP_Pb  108  470  124  488)
# --------
# PP_Pb
# A115S099AF06001_Dft
# data(filename='A115S099AF06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1455  A115S099AF06001_Dft    11      8     PP_Pb  158  391  169  399)
# --------
# Udev
# A115S09KBN08002_Dft
# data(filename='A115S09KBN08002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2481  A115S09KBN08002_Dft    11      9      Udev  120  410  131  419)
# --------
# PP_Pb
# A115S09MAC07001_Dft
# data(filename='A115S09MAC07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1456  A115S09MAC07001_Dft     7     10     PP_Pb   17   41   24   51)
# --------
# Udev
# A115S09MAF08001_Dft
# data(filename='A115S09MAF08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2482  A115S09MAF08001_Dft     5      8      Udev    4  220    9  228)
# --------
# Udev
# A115S09MAL05001_Dft
# data(filename='A115S09MAL05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2483  A115S09MAL05001_Dft    20     29      Udev   86  487  106  516)
# --------
# Udev
# A115S09TCA01001_Dft
# data(filename='A115S09TCA01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2484  A115S09TCA01001_Dft     6      8      Udev  155  415  161  423)
# --------
# PP_Pb
# A115S0A2CE06001_Dft
# data(filename='A115S0A2CE06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1457  A115S0A2CE06001_Dft     9     10     PP_Pb   16  346   25  356)
# --------
# Udev
# A115S0ARAL06002_Dft
# data(filename='A115S0ARAL06002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2485  A115S0ARAL06002_Dft    12     19      Udev    2  491   14  510)
# --------
# PP_Pb
# A115S0ARAW04001_Dft
# data(filename='A115S0ARAW04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1458  A115S0ARAW04001_Dft     9      8     PP_Pb   15   39   24   47)
# --------
# Udev
# A115S0ARCC03001_Dft
# data(filename='A115S0ARCC03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2486  A115S0ARCC03001_Dft    21     23      Udev   93  400  114  423)
# --------
# PP_Pb
# A115T007AG03001_Dft
# data(filename='A115T007AG03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1459  A115T007AG03001_Dft    10      9     PP_Pb  159  284  169  293)
# --------
# PP_Pb
# A115T007AG05001_Dft
# data(filename='A115T007AG05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1460  A115T007AG05001_Dft    13     12     PP_Pb   16  364   29  376)
# --------
# PP_Pb
# A115T01BBQ04001_Dft
# data(filename='A115T01BBQ04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1461  A115T01BBQ04001_Dft     8     41     PP_Pb    3  225   11  266)
# --------
# PP_Pb
# A115T01NAS02001_Dft
# data(filename='A115T01NAS02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1462  A115T01NAS02001_Dft   146    129     PP_Pb   10  374  156  503)
# --------
# PP_Pb
# A115T01NBK02002_Dft
# data(filename='A115T01NBK02002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1463  A115T01NBK02002_Dft    26     26     PP_Pb    2  191   28  217)
# --------
# PP_Pb
# A115T02JBU02001_Dft
# data(filename='A115T02JBU02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1464  A115T02JBU02001_Dft    10     10     PP_Pb   17  195   27  205)
# --------
# Udev
# A115T03SAA04001_Dft
# data(filename='A115T03SAA04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2487  A115T03SAA04001_Dft    17     37      Udev    1   18   18   55)
# --------
# PP_Pb
# A115T04MBW05001_Dft
# data(filename='A115T04MBW05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1465  A115T04MBW05001_Dft    12      8     PP_Pb   17  324   29  332)
# --------
# Udev
# A115T06UAW06001_Dft
# data(filename='A115T06UAW06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2488  A115T06UAW06001_Dft    11     13      Udev   57  433   68  446)
# --------
# PP_Pb
# A115T06UBM01001_Dft
# data(filename='A115T06UBM01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1466  A115T06UBM01001_Dft     7     12     PP_Pb  160   68  167   80)
# --------
# Udev
# A115T06UBT01001_Dft
# data(filename='A115T06UBT01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2489  A115T06UBT01001_Dft    23     23      Udev   32  412   55  435)
# --------
# PP_Pb
# A115T06UBT05001_Dft
# data(filename='A115T06UBT05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1467  A115T06UBT05001_Dft     7      7     PP_Pb  155   77  162   84)
# --------
# PP_Pb
# A115T06VAQ02002_Dft
# data(filename='A115T06VAQ02002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1468  A115T06VAQ02002_Dft    25     28     PP_Pb  147  143  172  171)
# --------
# PP_Pb
# A115T07XBE06001_Dft
# data(filename='A115T07XBE06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1469  A115T07XBE06001_Dft     7      7     PP_Pb  158   72  165   79)
# --------
# Udev
# A115T07XCF07001_Dft
# data(filename='A115T07XCF07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2490  A115T07XCF07001_Dft    20     21      Udev   33  415   53  436)
# --------
# Udev
# A115T07YAC05001_Dft
# data(filename='A115T07YAC05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2491  A115T07YAC05001_Dft    18     17      Udev   34  417   52  434)
# --------
# PP_Pb
# A115T080AC07001_Dft
# data(filename='A115T080AC07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1470  A115T080AC07001_Dft    50     66     PP_Pb  109  401  159  467)
# --------
# Udev
# A115U01KAL04001_Dft
# data(filename='A115U01KAL04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2492  A115U01KAL04001_Dft    21     20      Udev   34  416   55  436)
# --------
# PP_Pb
# A115U01KAL05003_Dft
# data(filename='A115U01KAL05003_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1471  A115U01KAL05003_Dft    23     13     PP_Pb  146  305  169  318)
# --------
# PP_Pb
# A115U01KAQ03001_Dft
# data(filename='A115U01KAQ03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1472  A115U01KAQ03001_Dft    10     10     PP_Pb   14  128   24  138)
# --------
# PP_Pb
# A115U01KAQ06001_Dft
# data(filename='A115U01KAQ06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1473  A115U01KAQ06001_Dft     6      6     PP_Pb  161   45  167   51)
# --------
# PP_Pb
# A115U01KAV04001_Dft
# data(filename='A115U01KAV04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1474  A115U01KAV04001_Dft     5      7     PP_Pb   19   99   24  106)
# --------
# PP_Pb
# A115U01LBT01001_Dft
# data(filename='A115U01LBT01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1475  A115U01LBT01001_Dft     4      6     PP_Pb   21  117   25  123)
# --------
# Udev
# A115U024AP04002_Dft
# data(filename='A115U024AP04002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2493  A115U024AP04002_Dft     6      4      Udev  159  408  165  412)
# --------
# PP_Pb
# A115U02ABA08001_Dft
# data(filename='A115U02ABA08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1476  A115U02ABA08001_Dft    10      9     PP_Pb   17  307   27  316)
# --------
# Udev
# A115U036AF08002_Dft
# data(filename='A115U036AF08002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2494  A115U036AF08002_Dft     9     15      Udev  157  403  166  418)
# --------
# PP_Pb
# A115U036AN01001_Dft
# data(filename='A115U036AN01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1477  A115U036AN01001_Dft    10     10     PP_Pb   15  191   25  201)
# --------
# PP_Pb
# A115U036AV07001_Dft
# data(filename='A115U036AV07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1478  A115U036AV07001_Dft    14     15     PP_Pb   12   84   26   99)
# --------
# PP_Pb
# A115U03ACG05001_Dft
# data(filename='A115U03ACG05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1479  A115U03ACG05001_Dft     4      7     PP_Pb  158  213  162  220)
# --------
# PP_Pb
# A115U03ACH01002_Dft
# data(filename='A115U03ACH01002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1480  A115U03ACH01002_Dft    18     17     PP_Pb  149   83  167  100)
# --------
# PP_Pb
# A115U04LBM02002_Dft
# data(filename='A115U04LBM02002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1481  A115U04LBM02002_Dft     5      5     PP_Pb  156   56  161   61)
# --------
# PP_Pb
# A115U04LBM03001_Dft
# data(filename='A115U04LBM03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1482  A115U04LBM03001_Dft     4      8     PP_Pb   19   58   23   66)
# --------
# PP_Pb
# A115U04LBM03002_Dft
# data(filename='A115U04LBM03002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1483  A115U04LBM03002_Dft     5      8     PP_Pb  159  292  164  300)
# --------
# PP_Pb
# A115U04LBM05001_Dft
# data(filename='A115U04LBM05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1484  A115U04LBM05001_Dft     6      8     PP_Pb  160  368  166  376)
# --------
# PP_Pb
# A115U04LBT05001_Dft
# data(filename='A115U04LBT05001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1485  A115U04LBT05001_Dft     9      8     PP_Pb   16  297   25  305)
# --------
# Udev
# A115U074BF02001_Dft
# data(filename='A115U074BF02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2495  A115U074BF02001_Dft    14     15      Udev   36  416   50  431)
# --------
# Udev
# A115U075AL01001_Dft
# data(filename='A115U075AL01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2496  A115U075AL01001_Dft    21     21      Udev   32  413   53  434)
# --------
# Udev
# A115U076BV02001_Dft
# data(filename='A115U076BV02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2497  A115U076BV02001_Dft    21     20      Udev   33  411   54  431)
# --------
# Udev
# A115U079CE04001_Dft
# data(filename='A115U079CE04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2498  A115U079CE04001_Dft    21     21      Udev   32  413   53  434)
# --------
# Udev
# A115U082BQ08001_Dft
# data(filename='A115U082BQ08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2499  A115U082BQ08001_Dft    23     24      Udev   82  483  105  507)
# --------
# PP_Pb
# A115U082BY08001_Dft
# data(filename='A115U082BY08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1486  A115U082BY08001_Dft     9      9     PP_Pb   15  244   24  253)
# --------
# PP_Pb
# A115U084AJ07001_Dft
# data(filename='A115U084AJ07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1487  A115U084AJ07001_Dft     7     13     PP_Pb   23  378   30  391)
# --------
# Udev
# A115U0A5AN03001_Dft
# data(filename='A115U0A5AN03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2500  A115U0A5AN03001_Dft     2      3      Udev  149  406  151  409)
# --------
# PP_Pb
# A115U0A5AV01001_Dft
# data(filename='A115U0A5AV01001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1488  A115U0A5AV01001_Dft    18     22     PP_Pb   10  382   28  404)
# --------
# PP_Pb
# A115U0A5AV02001_Dft
# data(filename='A115U0A5AV02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1489  A115U0A5AV02001_Dft    11     17     PP_Pb   15  275   26  292)
# --------
# PP_Pb
# A115U0AUAG02001_Dft
# data(filename='A115U0AUAG02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1490  A115U0AUAG02001_Dft    10     11     PP_Pb  150  385  160  396)
# --------
# Udev
# A115V00PCD02001_Dft
# data(filename='A115V00PCD02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 2501  A115V00PCD02001_Dft    29      2      Udev   80  518  109  520)
# --------
# PP_Pb
# A115V00SBG04001_Dft
# data(filename='A115V00SBG04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1491  A115V00SBG04001_Dft    10     10     PP_Pb  153  251  163  261)
# --------
# PP_Pb
# A115V03DBT02001_Dft
# data(filename='A115V03DBT02001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1492  A115V03DBT02001_Dft    10     12     PP_Pb   16  269   26  281)
# --------
# PP_Pb
# A115V03DBT07001_Dft
# data(filename='A115V03DBT07001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1493  A115V03DBT07001_Dft    10      9     PP_Pb   16  274   26  283)
# --------
# PP_Pb
# A115W026BL06001_Dft
# data(filename='A115W026BL06001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1494  A115W026BL06001_Dft    12      9     PP_Pb  122  446  134  455)
# --------
# PP_Pb
# A115W026BL08001_Dft
# data(filename='A115W026BL08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1495  A115W026BL08001_Dft     8      9     PP_Pb   16  336   24  345)
# --------
# PP_Pb
# A115W03KCD03001_Dft
# data(filename='A115W03KCD03001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1496  A115W03KCD03001_Dft     5     10     PP_Pb  159  174  164  184)
# --------
# PP_Pb
# A115W03KCD04002_Dft
# data(filename='A115W03KCD04002_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1497  A115W03KCD04002_Dft     6      6     PP_Pb   19  286   25  292)
# --------
# PP_Pb
# A115W04JBJ04001_Dft
# data(filename='A115W04JBJ04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1498  A115W04JBJ04001_Dft     4      8     PP_Pb   17   94   21  102)
# --------
# PP_Pb
# A115X01JBL04001_Dft
# data(filename='A115X01JBL04001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1499  A115X01JBL04001_Dft     7     10     PP_Pb  157   82  164   92)
# --------
# PP_Pb
# A115X01JBL08001_Dft
# data(filename='A115X01JBL08001_Dft', object=                 filename width height className xmin ymin xmax ymax
# 1500  A115X01JBL08001_Dft    12     14     PP_Pb  153  376  165  390)
# --------

# %%
classNames = [os.path.join("東捷科技_20220504_ADC_釋出資料集_origin", filename) for filename in os.listdir("東捷科技_20220504_ADC_釋出資料集_origin") ]

# %%
path = []
for className in classNames:
    for i in os.listdir(className):
        if i[-3:]=="bmp":
            if "bound" not in i:
                path.append([className.split("\\")[-1],os.path.join('{}',i).format(className)])
random.shuffle(path)
len(path)
# Out:
# 3003

# %%
path[0]
# Out:
# ['PP', '東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K05ACA08002_Dft.bmp']

# %%
import shutil
for file_name in path[:2400]:
    train_path = "train/"+file_name[0]
    if(os.path.isdir(train_path)==False):
        os.makedirs(train_path)
    if os.path.isfile(file_name[1]):
        shutil.copy(file_name[1], train_path)
    xml_file_name = file_name[1].replace(".bmp",".xml")
    if os.path.isfile(xml_file_name):
        shutil.copy(xml_file_name, train_path)

# %%
path[2401]
# Out:
# ['PP_Pb', '東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K069BC03001_Dft.bmp']

# %%
IMAGE_PATHS = []
for file_name in path[2400:]:
    test_path = "test/"+file_name[0]
    if(os.path.isdir(test_path)==False):
        os.makedirs(test_path)
    if os.path.isfile(file_name[1]):
        shutil.copy(file_name[1], test_path)
        IMAGE_PATHS.append(test_path+"/"+file_name[1])
    xml_file_name = file_name[1].replace(".bmp",".xml")
    if os.path.isfile(xml_file_name):
        shutil.copy(xml_file_name, test_path)

# %%
IMAGE_PATHS
# Out:
# ['test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114K03XCK07003_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K069BC03001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115M07ABE04001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114U03YBQ02002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114R057AT02002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114R086BV05001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115J011BL01001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A1153075BC05001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114R06TBP01001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114E02LCE03004_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H00QCD05001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115A08QCD07010_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114U019AQ01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115L05CAJ02001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114M04HBE06001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05BAB06001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115B064AS04001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116501GAW01001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114S00ACJ08003_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H042CK03001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114S067BX03002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115M06WCK02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J02CAV02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114W048BD01002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115T01NAS02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H052CH02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H050BL07002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115N089BN01002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114P04BCH03001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114D077AL08005_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N06CBX01001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N012AY04001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114Q03HAU07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115L009CE02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K0A0AN04001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J03XBX06001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115J022CF05001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K05RBY08001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05VBX05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N05EBX08001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114N069CE01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116404CAP01003_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N03CAP01003_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114V067BE04001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114V03NAQ06001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J02ACB07002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114P005BH01002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J02JBU02002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K04MBS02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115D0A2CC03001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114S00RBV01002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05ABY01002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114H052CJ02001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115H06PBR03002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114L08EBU02002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05XAW02001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114M06LAE08001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114V03FBP04002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115J020BR03002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116401XAB05003_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115K03YAJ01001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K051BV05004_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115H022BQ08001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K00FAV07001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T07FBB01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115D0A4CK03001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R07GAA03004_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H042CC04001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H043BQ01005_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115S02WBB06001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N042BE06001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K05SAQ03002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115U083AT01005_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H043BM06001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115L034BL06001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K038BK02003_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114L011AD03002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114F061AE08002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N043AU04001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114J051AX01002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115D05TBB02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115P06GAC02001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115U024AP04002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J02ACA02003_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114L08KAE08003_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114T02PBL04002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114K038AY01001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114K01HBB08002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114T03KCG04001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114P02PBC04001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115J06MBL08001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115T07YAC05001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114G01WBF08001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115P003BB08001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H04AAC07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115A07GBY07001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115R03LAL08001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114M083AE03001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114S09RAQ08004_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K01CCB03002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115U00LAK08001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114R06TBA01001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114W048BW02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114W048BL01001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114M02TBC03001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J04QAG04002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114P03NBQ08002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114H051BM07001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114J05HBK04001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115L029BS05001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114R018CH02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114F01HCC03001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115M07BAP07001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K00FBN04001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115F07TAR03001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114Q057AE06001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114V051CC08001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114Q045AF07002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R009BC07004_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114R08WAJ02002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115D0A2CH07001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115R03NAH07002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K038AC08002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K04VCD03004_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T02SBD03002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A1153069BT01002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114S009AX08002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114J03YBT03001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T02RAS03002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115501GAF02003_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114N08CAU03001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114D042CA08004_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114H043BC04003_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K01CBV01001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114J02KBS01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114N012AV01002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114J02KAN07001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114T06GAQ01001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114M06TAU05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114Q04XBU05001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K051BV05003_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114P05GAW05002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K01GBD03001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K05XBV02001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115J023AC06006_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114N01SBV01001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114S081AD08001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K038AH05001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114T028BJ06001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114V02ABN02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05XCH08001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114P049BH07001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K09TBA06002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115L006CD02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J03YBE07001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115H05RAR04001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114S07HBE05001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114N043BH03001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115J00BAH05001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A1152055AJ07001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114U05VAF04001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114K04UCH05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114G041AN08001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114K09TBA08002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K01CCC08001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K05QBW01001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115M07BAK05002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N05ECE03003_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114R06TBG08001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114H052CF08001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114R06LBS03002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K0A0AN05001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115M06WCK01001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115L01ECE06001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116401XAB06001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115J06MBN05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K05UBT05001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K03PAN01001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114R08WAB06002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114R087BN05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114J051BG06001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N07TAN07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115S00CBU02001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114T04WAN05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114Q01BBE02001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N05VCH02002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114S067BX07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115A07GCK05002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K05BAF03002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116501GAU03001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K071AU02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K05RBY04003_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114R087AL02002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H03GAB05001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J06EBW01002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115C06EBQ04001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115S0A2CE06001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K073BU03001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114N03NBR06001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114J03YBE08001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114U05QCH06001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K09WAF02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J00MBF01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114T031AY01001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115U036AV07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114T00KBJ02001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N05RAK07003_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115N07JAL01001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114Q00NCH01001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114R015CD08002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114K09WBE02001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115B02PCA01002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114S083AL08002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T06BBB05002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J03YBM02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H052BL04001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K03WBU08001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115L035AK01002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115S01KAE04001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115J04WBC06001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114M06TAL07001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K08EAJ01001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114P04FBV02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115N067AT08002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114U04HBT02002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114S00CAU05002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115K01DAB02002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114L011AG05001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116407FBW01001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N00AAJ06001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K00FAU05002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114R02TAL05001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115Q05MAG03001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114S09PCF07002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114L013AP06001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N05UAP08001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114Q010CF03002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115A07GCK05001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114K05XCC01001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K04VAJ06001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J00MCD06001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114Q037BM01001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114R00ECJ08004_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K079BE07001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115F00GBT02001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114U052BG08002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114S02FBQ02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J02ACB06002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N07VBH08002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115N07HAA02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05CBE08005_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114N06ACE07004_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116401TBS01003_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114R02VBV03005_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114J00CBG04001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H052BP03001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114N059AR05001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114T078BX01001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115L01WAL01001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K0A0AR07002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115A07ABF01001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115J06GCK03001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115R03QAT06001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R02TAQ05001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K04VAH03001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114N08LAT06001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114W04NAW03001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K08HBE05002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114W06KBK07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115M06WAA02001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114H051BY02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H00QCD02002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K09WAF06002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115U079CE04001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R08WBC02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114M028AR08001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115M00VAV03001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R08WAT07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115R014AN02001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115C05ECF06001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N03CAG07005_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114T01QCC01001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05TCD07006_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114J06DAA03008_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114V03NAB03003_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114F08LBF05005_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115J042AD07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115A07CAU02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K07EAG07001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114M06SBY06002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A1152037AF05001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115J039AP01002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114F00MAG06001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114T00KBM06001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114V05HAJ04001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114R06TBX05001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115H022BT01007_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T07DCA02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115M059BF02002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05XAW06001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H052BU07001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115105FAQ02002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N05BCC06006_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114J051AY03003_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114W04QBB03001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114J021BU07001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114M00TBS02001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114V02BAK01002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N043BD07001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J02CAW04001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T02RAP03001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115J01QAD04001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N020AG05001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114K05VBX07002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115D0A3BS04001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114W04PAX03001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115M059BC08001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114K05XAP02002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05CBE05005_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114S06GAH01002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114W07GCG01003_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114W046AC05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R02UBC06001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114S009AX08004_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114V03HBM02001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114K038BK02002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115704XBW01001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J06ECJ02002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115S08RAM02001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114R06TBE02001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114V03FCH02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K00DBP05002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114K05XAP04001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114K04SAB07005_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114H051AV04001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116B01NCC01001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05BAF03003_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115C07DCF08001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K037AR07001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114M064BR08006_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115A07CAT03002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114K01CBR02001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114V02FCF01001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J02JCK07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114T07RAE02001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115R03QCE06001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114V02BAY08001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115703JBG05001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114H04PCG06003_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115U04LBM05001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115M07CAC01002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R00BCE07002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114N043BJ01003_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N00AAE02005_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115L035AK05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114P04BCH06001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114K071BD08001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114H02UCJ08001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115T007AG05001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115B02PCB03001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115P08XBE08001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K04VCF01001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T02SAR07001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N03DBC04001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114Q00PCK01001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115K02UAP02002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114G02JCG01002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114D077AK03001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114M082AG03005_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115V00SBG04001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115H022BN03001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115L063BW01001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114U05QAN01001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114T06FAE08002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114T07FCC06001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115J04LCC03001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115S099AF06001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115A00YAR01001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114S09KBH08001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114R02TBU02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K09XCB01002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114T02RBJ04001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114N007AU08002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114R00EAD04001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115G02ACD02001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114L04FAM02001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114P05WAA04001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114U01PAG01001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114P00WAX06001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115L04UAK01001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114R06PAA02001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114K04TBF08002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114P01ACE06001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R02TAF07001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115X02RBJ01002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T045BP07001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114S07HAU07003_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115H05QBF01002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J05YBH01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114T031BC02001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114N03CAG03001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K00DBS05001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05TBK03001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K01CCB03001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R06TBJ05002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K03XBW07001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T07FAX02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115C09LAQ03002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114W01SBE02001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J06DAA06007_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114K00DBE01003_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A1153069BE01001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115T01NBK02002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114R08WAD01001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114S07GBX02001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115J02XBN03001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114F021AU06003_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114V007AT07001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115N002AW03001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114S00ACH01001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J02KAU03001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115T007AG01001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K04SAB06002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115N00KBQ06001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K038AS01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115G046AB05001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114U04GBS08001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115A00YAH05004_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114H02UCF06002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115D02TBA05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K05XBQ03002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115R028CE07002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114L011AM05002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114W02DCJ01004_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114P05RBN01002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J06EBY05001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K00DBG05001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115801RCA07002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114S09QCJ05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N08DCE07002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R00DAN01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114U019AT04001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115N01FAE04001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115E00UAK07001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115703GBC03001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H03GBB04001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114R01SBE06001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114K04VAJ01003_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114Q07EAX03002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115C08KAQ01001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114V00FBW07002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115D0B7AK07001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114K03XBJ06001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114H04PAU04001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N03DAN03001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H051AA03001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114V04DBJ07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115J06MBN02002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114S09KBE06001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J06DAA07002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114R016BX06001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115K00XBJ05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K08EBM08001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114S04QAV01001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114U05UBQ07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114J05HBL07001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115A07BBU03004_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N020AG08006_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115L073BP03001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114T028CF02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K069BE08001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114E07VCH03001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114V029AT04002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115A08QAR03003_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T00SAY04001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114U04HBC02001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115B00GCK01003_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J03XBU08003_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N039AL06002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H04PAU03001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115700XAC08001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114D023AB02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115N00KBN07001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114G008AF01002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N007BY04001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114J03YBW08001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114Q07EAE03001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114P05GBM01001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115C05VAJ07002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114Q00NCC02001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115101HBN04003_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114U023CJ06001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115U01KAL04001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114H043BC04001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115S09MAC07001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R018CC05001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114G02JCG03003_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114T02PBP06001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114N039AM08001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J02JBS02002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114S09KAD01002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K09YBK01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115J083BQ01001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K037AS02001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114H04AAC03001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114R00BCD01001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114N043AQ02001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115N05EAC05002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T02TAU05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N042BT06001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114U01SAY07001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114N03CAU05001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J04NBE05002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115D093AR03001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114K08HBM08001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114N043BD08001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114F048AE01002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116703DAH01001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05XBR07001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114L011AK01003_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K06ABN02001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114N042BX07006_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116308ABM01002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114T04QCC01001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114M055CG01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115N06WBW03001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114Q03JBK07004_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115J06MBH08001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T03KBQ08001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116702TAG01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115H046BL02002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H050BJ04002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K03WBR03001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N01SBW06002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115J05KCF06001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K01CBY04001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N042BT07001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114L082BE04007_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115K03PAK02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114V03QCJ04001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K09YBK02004_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115M07ACJ03002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114P008AL05001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T02QAQ01001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116408KAR01003_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114K032AQ01001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114M08GBW08001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114R018BH05001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A114N06ABV01001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J02ACB08003_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114H051CA04001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115C09CBY03002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114R06TAK08001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114T017AB04001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114T028BL01002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114F061AE06002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114S067CB08002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H043BT05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N042BW08001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115J00WAM01001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A115K067AK05001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N043AL03002_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115K002AH02001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114M08ABU01001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114M08BAV08001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H04PCA06001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A116501HAR02002_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114J03WAH08001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114S036AJ06001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115B032AV04003_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114N042BW04001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114L04GBK07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115S02XAY07001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114Q06EAR01002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J06ECB05001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K08HBS06001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115R005BY08001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114N059CA02002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K09UAV01001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J06EBY05002_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114P00MAP03001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114S04AAF03002_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114K05CBE05001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114S00CCA04001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114T06FAF06001_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115H045CA01001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115J063CD05001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114L011BR08001_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114U05WAF02001_Dft.bmp',
#  'test/Udev/東捷科技_20220504_ADC_釋出資料集_origin\\Udev\\A114T02QCE05001_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114J00MAY06002_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114S0ANBL06001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114K0A0AL01003_Dft.bmp',
#  'test/I_R/東捷科技_20220504_ADC_釋出資料集_origin\\I_R\\A114P006BM08001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114P00PAG03003_Dft.bmp',
#  'test/F_TP/東捷科技_20220504_ADC_釋出資料集_origin\\F_TP\\A115A07GCD04001_Dft.bmp',
#  'test/PP/東捷科技_20220504_ADC_釋出資料集_origin\\PP\\A114R01PAL07002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114V02DBJ01003_Dft.bmp',
#  'test/TP/東捷科技_20220504_ADC_釋出資料集_origin\\TP\\A114H03WBC01002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115S021BX03001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114U01JCH08002_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A115L035AF07001_Dft.bmp',
#  'test/PP_Pb/東捷科技_20220504_ADC_釋出資料集_origin\\PP_Pb\\A114P020AP06001_Dft.bmp']

# %%
for i in os.listdir(className[0]):
    if i[-3:]=="bmp":
        if "bound" not in i:
            print(i)
# Out:
# A114H051BM01002_Dft.bmp
# A114K00CCG03001_Dft.bmp
# A114K01BAJ05001_Dft.bmp
# A114K01CBR02001_Dft.bmp
# A114K01CBR05001_Dft.bmp
# A114K01CCA05001_Dft.bmp
# A114K01CCD01002_Dft.bmp
# A114K04SAB07001_Dft.bmp
# A114K04TBM02007_Dft.bmp
# A114K04TBM04003_Dft.bmp
# A114K04VAH05002_Dft.bmp
# A114K04VAJ01003_Dft.bmp
# A114K04VCF01003_Dft.bmp
# A114K051CD05002_Dft.bmp
# A114K05ACA01001_Dft.bmp
# A114K05BAK01002_Dft.bmp
# A114K05XCC01001_Dft.bmp
# A114K05XCC03001_Dft.bmp
# A114K08EAK03004_Dft.bmp
# A114K08EAK06001_Dft.bmp
# A114K0A4CA03002_Dft.bmp
# A114K0A4CA07001_Dft.bmp
# A114L011AD07001_Dft.bmp
# A114L011AE07001_Dft.bmp
# A114L011AG07001_Dft.bmp
# A114L011AK01003_Dft.bmp
# A114L011AQ02001_Dft.bmp
# A114L013AE02001_Dft.bmp
# A114L013AM02001_Dft.bmp
# A114L013AT01002_Dft.bmp
# A114L013AT01003_Dft.bmp
# A114L01VCC04002_Dft.bmp
# A114L01WCC02001_Dft.bmp
# A114L077BA01001_Dft.bmp
# A114M02CAF03001_Dft.bmp
# A114M02CAH01001_Dft.bmp
# A114M046AW01004_Dft.bmp
# A114M04HBE04001_Dft.bmp
# A114M06LAE08001_Dft.bmp
# A114M083BW04001_Dft.bmp
# A114M083BW06001_Dft.bmp
# A114M083BX08001_Dft.bmp
# A114N012AV01002_Dft.bmp
# A114N020AG04001_Dft.bmp
# A114N02JBD01001_Dft.bmp
# A114N03CAG03001_Dft.bmp
# A114N03CAH03001_Dft.bmp
# A114N03CAN01002_Dft.bmp
# A114N03CAP01001_Dft.bmp
# A114N03CAU05001_Dft.bmp
# A114N03DCG01003_Dft.bmp
# A114N043AP03001_Dft.bmp
# A114N043AX03002_Dft.bmp
# A114N043AX04001_Dft.bmp
# A114N043BJ07001_Dft.bmp
# A114N043BP01008_Dft.bmp
# A114N059CH01001_Dft.bmp
# A114N059CH01002_Dft.bmp
# A114N059CH01005_Dft.bmp
# A114N059CJ01002_Dft.bmp
# A114N059CJ01003_Dft.bmp
# A114N05ACJ01002_Dft.bmp
# A114N069CE01001_Dft.bmp
# A114N06AAQ07002_Dft.bmp
# A114N06ABV01001_Dft.bmp
# A114N06ACE01001_Dft.bmp
# A114N06DCK01002_Dft.bmp
# A114P005AX05001_Dft.bmp
# A114P005BH01002_Dft.bmp
# A114P005BH05002_Dft.bmp
# A114P005BS08002_Dft.bmp
# A114P005CB03001_Dft.bmp
# A114P005CB08001_Dft.bmp
# A114P005CC03002_Dft.bmp
# A114P022CC03001_Dft.bmp
# A114P031AC01002_Dft.bmp
# A114P03PAR03001_Dft.bmp
# A114P03SBS04001_Dft.bmp
# A114P04BBR02001_Dft.bmp
# A114P04BBR05001_Dft.bmp
# A114P05GBA01002_Dft.bmp
# A114P05GBA01003_Dft.bmp
# A114P05GBA01005_Dft.bmp
# A114P05GBH06001_Dft.bmp
# A114P05GBY05002_Dft.bmp
# A114P05RBN01002_Dft.bmp
# A114P05RBR01002_Dft.bmp
# A114P05RBX01001_Dft.bmp
# A114Q03HAU05001_Dft.bmp
# A114Q03JBK01002_Dft.bmp
# A114Q03JBK03002_Dft.bmp
# A114Q03JBN08001_Dft.bmp
# A114Q06EAC07001_Dft.bmp
# A114Q06EAD01001_Dft.bmp
# A114Q07LAF02001_Dft.bmp
# A114R01PBQ04002_Dft.bmp
# A114R01PBR05001_Dft.bmp
# A114R01PBS05001_Dft.bmp
# A114R01SBR01004_Dft.bmp
# A114R01SBR01014_Dft.bmp
# A114R01SBR04002_Dft.bmp
# A114R01WBN07001_Dft.bmp
# A114R02TBM01001_Dft.bmp
# A114R030AE05001_Dft.bmp
# A114R04YAD08001_Dft.bmp
# A114R06LBS03002_Dft.bmp
# A114R06TBE02001_Dft.bmp
# A114R06TBG06002_Dft.bmp
# A114R06TBK03001_Dft.bmp
# A114R06TBP01001_Dft.bmp
# A114R06TBX02002_Dft.bmp
# A114R06TBX05001_Dft.bmp
# A114R06TBY01001_Dft.bmp
# A114R06TBY05001_Dft.bmp
# A114R087AG03002_Dft.bmp
# A114R087BM01003_Dft.bmp
# A114R08WAB04001_Dft.bmp
# A114R08WAD01001_Dft.bmp
# A114S009CG05001_Dft.bmp
# A114S00ACH01001_Dft.bmp
# A114S00RBV01002_Dft.bmp
# A114S04PCH03001_Dft.bmp
# A114S067BV01008_Dft.bmp
# A114S067BX01003_Dft.bmp
# A114S067BX03002_Dft.bmp
# A114S09KAD01001_Dft.bmp
# A114S09KAD01002_Dft.bmp
# A114S09KAD01003_Dft.bmp
# A114S09KAU03002_Dft.bmp
# A114S0ANAA03001_Dft.bmp
# A114T028CF02001_Dft.bmp
# A114T028CF02003_Dft.bmp
# A114T028CF05001_Dft.bmp
# A114T028CG08001_Dft.bmp
# A114T02HBY05002_Dft.bmp
# A114T02KAD05001_Dft.bmp
# A114T02NAN07001_Dft.bmp
# A114T02PBL04002_Dft.bmp
# A114T02RBW04001_Dft.bmp
# A114T02TBS03007_Dft.bmp
# A114T02TBS03008_Dft.bmp
# A114T02TBS03011_Dft.bmp
# A114T02TBS06003_Dft.bmp
# A114T02TBS06004_Dft.bmp
# A114T031AY01001_Dft.bmp
# A114T031BC02001_Dft.bmp
# A114T03DAY07001_Dft.bmp
# A114T03DBG01001_Dft.bmp
# A114T045AY07003_Dft.bmp
# A114T045BX01004_Dft.bmp
# A114T06BBB01001_Dft.bmp
# A114T06FAD08001_Dft.bmp
# A114T06GBW03003_Dft.bmp
# A114T078BX01001_Dft.bmp
# A114T078BX01002_Dft.bmp
# A114U019AQ01001_Dft.bmp
# A114U019AT04001_Dft.bmp
# A114U019CK03001_Dft.bmp
# A114U01GBV01001_Dft.bmp
# A114U01GBV03001_Dft.bmp
# A114U01GBV03002_Dft.bmp
# A114U01MCJ01001_Dft.bmp
# A114U01PAG01001_Dft.bmp
# A114U01SAY07001_Dft.bmp
# A114U01SCG01001_Dft.bmp
# A114U01SCG05002_Dft.bmp
# A114U01TAH04001_Dft.bmp
# A114U02HBF03002_Dft.bmp
# A114U02QAW01001_Dft.bmp
# A114U034AV03002_Dft.bmp
# A114U04CAL08001_Dft.bmp
# A114U052AK01001_Dft.bmp
# A114U054AA01001_Dft.bmp
# A114U054BT03002_Dft.bmp
# A114U05QCH06001_Dft.bmp
# A114U061AH03001_Dft.bmp
# A114V02ABH01003_Dft.bmp
# A114V02ABM04001_Dft.bmp
# A114V02ABM05001_Dft.bmp
# A114V02BAK06001_Dft.bmp
# A114V02FCF01001_Dft.bmp
# A114V03FCH02001_Dft.bmp
# A114V03NAB03003_Dft.bmp
# A114V03UBF01002_Dft.bmp
# A114V047CE01001_Dft.bmp
# A114W02DCE01003_Dft.bmp
# A114W02DCE05003_Dft.bmp
# A114W02DCJ01004_Dft.bmp
# A114W02JBE04002_Dft.bmp
# A114W046AC05001_Dft.bmp
# A114W048AY01002_Dft.bmp
# A114W048BJ05001_Dft.bmp
# A114W04PAX03001_Dft.bmp
# A114W04PAY05001_Dft.bmp
# A114W04QBB03001_Dft.bmp
# A114W04QBB06001_Dft.bmp
# A114W06KBK07001_Dft.bmp
# A114W06KBL05001_Dft.bmp
# A114W06MCG01002_Dft.bmp
# A114W07GCC03001_Dft.bmp
# A114W07GCG01003_Dft.bmp
# A115101HBA07001_Dft.bmp
# A115101HBC03002_Dft.bmp
# A115101HBD01002_Dft.bmp
# A115101HBN03004_Dft.bmp
# A115101HBN03005_Dft.bmp
# A115101HBN04003_Dft.bmp
# A115101HBQ01002_Dft.bmp
# A115103EAB07002_Dft.bmp
# A115103EBB01001_Dft.bmp
# A115103EBL06001_Dft.bmp
# A115104MBT01001_Dft.bmp
# A115105FAQ02002_Dft.bmp
# A1151069AX07001_Dft.bmp
# A115106VBD01002_Dft.bmp
# A115201TAN05001_Dft.bmp
# A1152036BA01001_Dft.bmp
# A1152037AF05001_Dft.bmp
# A1152038BU01001_Dft.bmp
# A115203AAL01001_Dft.bmp
# A1152055AJ03001_Dft.bmp
# A1152055AJ07001_Dft.bmp
# A1152070AF02001_Dft.bmp
# A115301TBX01001_Dft.bmp
# A115304HAD03001_Dft.bmp
# A115305PAM05001_Dft.bmp
# A1153069BE01001_Dft.bmp
# A1153069BE01003_Dft.bmp
# A1153069BR01001_Dft.bmp
# A1153069BT01002_Dft.bmp
# A115306CAA01001_Dft.bmp
# A1153074AK02001_Dft.bmp
# A1153075AT01001_Dft.bmp
# A115402EBM01002_Dft.bmp
# A115403TBQ02001_Dft.bmp
# A115404PBY07001_Dft.bmp
# A115404XBY08001_Dft.bmp
# A115406EBE05001_Dft.bmp
# A115501GAF02003_Dft.bmp
# A115501GAF04001_Dft.bmp
# A115504DBU03001_Dft.bmp
# A115603QBD05001_Dft.bmp
# A115603QBE07003_Dft.bmp
# A115604BBL01002_Dft.bmp
# A115605QBN01001_Dft.bmp
# A115700XAC08001_Dft.bmp
# A115700XAH01007_Dft.bmp
# A115702XCF01002_Dft.bmp
# A115703GAV01001_Dft.bmp
# A115703GBC03001_Dft.bmp
# A115703GBM01002_Dft.bmp
# A115703JBG05001_Dft.bmp
# A115703JBR01004_Dft.bmp
# A115704VBQ01002_Dft.bmp
# A115704VBQ03001_Dft.bmp
# A115704XBW01001_Dft.bmp
# A115706CBV01002_Dft.bmp
# A115707MBE05002_Dft.bmp
# A115800DCE01001_Dft.bmp
# A115800SCH05001_Dft.bmp
# A115800VAD01001_Dft.bmp
# A115801RCA07002_Dft.bmp
# A115805QAM02001_Dft.bmp
# A115805QAM03001_Dft.bmp
# A115805RCH01001_Dft.bmp
# A115805UBV02001_Dft.bmp
# A115806HBG01001_Dft.bmp
# A115806HBP05001_Dft.bmp
# A115900CBR01002_Dft.bmp
# A115900FAL01001_Dft.bmp
# A115902TBP01002_Dft.bmp
# A115902TBV01001_Dft.bmp
# A115903WAB03001_Dft.bmp
# A115903WAB03002_Dft.bmp
# A115903WAB07001_Dft.bmp
# A115904NCE03002_Dft.bmp
# A115907BAS01001_Dft.bmp
# A115908GAS08001_Dft.bmp
# A115908XCA08001_Dft.bmp
# A115A00YAH05004_Dft.bmp
# A115A00YAR01001_Dft.bmp
# A115A039BM01002_Dft.bmp
# A115A07ABF01001_Dft.bmp
# A115A07BBU03002_Dft.bmp
# A115A07BBU03004_Dft.bmp
# A115A07BBW05002_Dft.bmp
# A115A07BCB01001_Dft.bmp
# A115A07GCD04001_Dft.bmp
# A115A07GCE07002_Dft.bmp
# A115A08QAR03002_Dft.bmp
# A115A08QAR03003_Dft.bmp
# A115A0AGAV02001_Dft.bmp
# A115A0AGBB05001_Dft.bmp
# A115A0AGBN08001_Dft.bmp
# A115B00GCK01003_Dft.bmp
# A115B02PCA01001_Dft.bmp
# A115B02PCA01002_Dft.bmp
# A115B02PCD07001_Dft.bmp
# A115B02PCG03001_Dft.bmp
# A115B032AV04003_Dft.bmp
# A115B03WCF01001_Dft.bmp
# A115B067AB03001_Dft.bmp
# A115B067AB03002_Dft.bmp
# A115B06YAL05001_Dft.bmp
# A115B06YBY03001_Dft.bmp
# A115B071AV07001_Dft.bmp
# A115C04TAF01001_Dft.bmp
# A115C04TBS06001_Dft.bmp
# A115C06EBQ04001_Dft.bmp
# A115C07DBK01001_Dft.bmp
# A115C07GAG03001_Dft.bmp
# A115C07GAR01009_Dft.bmp
# A115C08HCK07001_Dft.bmp
# A115C08HCK07002_Dft.bmp
# A115C08KAR05001_Dft.bmp
# A115C08SBX03001_Dft.bmp
# A115C09CCE05001_Dft.bmp
# A115D00KCG07001_Dft.bmp
# A115D023AH07002_Dft.bmp
# A115D03FCF03001_Dft.bmp
# A115D05TAY07001_Dft.bmp
# A115D05TBB03002_Dft.bmp
# A115D063AG01002_Dft.bmp
# A115D090BV02002_Dft.bmp
# A115D093BG01001_Dft.bmp
# A115D093BM01001_Dft.bmp
# A115D093BQ03001_Dft.bmp
# A115D093BQ03002_Dft.bmp
# A115D0A2CH02002_Dft.bmp
# A115D0A4CH03001_Dft.bmp
# A115D0A4CK02001_Dft.bmp
# A115D0A4CK03001_Dft.bmp
# A115E00UAK07001_Dft.bmp
# A115E00VAB01001_Dft.bmp
# A115E01DAB05001_Dft.bmp
# A115E01DAB06001_Dft.bmp
# A115E04CAH07002_Dft.bmp
# A115F00GBT02001_Dft.bmp
# A115F00NAN03001_Dft.bmp
# A115F01SAS01001_Dft.bmp
# A115F01SAS01011_Dft.bmp
# A115F030AQ07001_Dft.bmp
# A115F05JBR06001_Dft.bmp
# A115F05JBU01001_Dft.bmp
# A115F06TBG04001_Dft.bmp
# A115F07TAR03001_Dft.bmp
# A115F09LBX08001_Dft.bmp
# A115G040AD01002_Dft.bmp
# A115G046AB04001_Dft.bmp
# A115G046AB05001_Dft.bmp
# A115G04SAP01002_Dft.bmp
# A115G060BH02001_Dft.bmp
# A115G060BK01001_Dft.bmp
# A115G060BW05001_Dft.bmp
# A115H022BT01007_Dft.bmp
# A115H022BV07001_Dft.bmp
# A115H02AAY08001_Dft.bmp
# A115H045AB01001_Dft.bmp
# A115H045CA01001_Dft.bmp
# A115H046BL02002_Dft.bmp
# A115H04JAK01001_Dft.bmp
# A115H04JAM03001_Dft.bmp
# A115H05PBR01002_Dft.bmp
# A115H05QBF01002_Dft.bmp
# A115H06PBN07001_Dft.bmp
# A115H06PBR03001_Dft.bmp
# A115H06PBR03002_Dft.bmp
# A115H06PBR05002_Dft.bmp
# A115H07KAC04002_Dft.bmp
# A115H087CG05001_Dft.bmp
# A115J00BAH05001_Dft.bmp
# A115J00VAS07001_Dft.bmp
# A115J00XBE01002_Dft.bmp
# A115J011BL01001_Dft.bmp
# A115J037BT03001_Dft.bmp
# A115J03VAX04002_Dft.bmp
# A115J03VAX04003_Dft.bmp
# A115J04WBC06001_Dft.bmp
# A115J04YAK05001_Dft.bmp
# A115J05KBV07001_Dft.bmp
# A115J05KCF06001_Dft.bmp
# A115J05LBC01001_Dft.bmp
# A115J067BX01003_Dft.bmp
# A115J067BX07002_Dft.bmp
# A115J067CD05002_Dft.bmp
# A115J067CG01002_Dft.bmp
# A115J06MBL08001_Dft.bmp
# A115J083BQ01001_Dft.bmp
# A115K002AH02001_Dft.bmp
# A115K00QBL01001_Dft.bmp
# A115K00QBL03001_Dft.bmp
# A115K00QBP03001_Dft.bmp
# A115K00XAW02001_Dft.bmp
# A115K00YBE02001_Dft.bmp
# A115K02TBS03001_Dft.bmp
# A115K03YAG05001_Dft.bmp
# A115K03YAJ01001_Dft.bmp
# A115K03YAK05001_Dft.bmp
# A115K03YAL07001_Dft.bmp
# A115K04MAQ03001_Dft.bmp
# A115K04TBK01001_Dft.bmp
# A115K05RAP06001_Dft.bmp
# A115K05RAQ04001_Dft.bmp
# A115K067AJ02001_Dft.bmp
# A115K069BY03003_Dft.bmp
# A115K06AAL02001_Dft.bmp
# A115K070AG01003_Dft.bmp
# A115K075BK01001_Dft.bmp
# A115K078AC06001_Dft.bmp
# A115L00DAC06001_Dft.bmp
# A115L00DBH05001_Dft.bmp
# A115L00DBH07001_Dft.bmp
# A115L00DCK03001_Dft.bmp
# A115L00EBF01001_Dft.bmp
# A115L01GCJ05001_Dft.bmp
# A115L01MBE05001_Dft.bmp
# A115L034AE02001_Dft.bmp
# A115L034AQ01001_Dft.bmp
# A115L035AK03001_Dft.bmp
# A115L035AK05001_Dft.bmp
# A115L04LCC05001_Dft.bmp
# A115L05CAJ02001_Dft.bmp
# A115L060BE03001_Dft.bmp
# A115L063BW01001_Dft.bmp
# A115L070BY04001_Dft.bmp
# A115M01WCJ01001_Dft.bmp
# A115M05AAB01001_Dft.bmp
# A115M05AAB03003_Dft.bmp
# A115M07BBV06002_Dft.bmp
# A115N002AW03001_Dft.bmp
# A115N002BW01001_Dft.bmp
# A115N023CC06001_Dft.bmp
# A115N02RAU04001_Dft.bmp
# A115N02RBB07001_Dft.bmp
# A115N03EAC07001_Dft.bmp
# A115N06WBW01004_Dft.bmp
# A115N06WBW03001_Dft.bmp
# A115N089BA02001_Dft.bmp
# A115N089BJ02002_Dft.bmp
# A115Q020AE01004_Dft.bmp
# A115Q02UAC02001_Dft.bmp
# A115R028CE07002_Dft.bmp
# A115R02TBU01002_Dft.bmp
# A115R02TBV05001_Dft.bmp
# A115R02UAY01001_Dft.bmp
# A115R04XCE03001_Dft.bmp
# A115S02RBY04002_Dft.bmp
# A115S079AV01002_Dft.bmp
# A115S0ARAV07002_Dft.bmp
# A115T007AG01001_Dft.bmp
# A115T02RBT01001_Dft.bmp
# A115T02RBW03001_Dft.bmp
# A115T02RBW08001_Dft.bmp
# A115T080AC02001_Dft.bmp
# A115U00LAK08001_Dft.bmp
# A115U01FBW01002_Dft.bmp
# A115U01LBY05001_Dft.bmp
# A115U02ACA03001_Dft.bmp
# A115U075AH01004_Dft.bmp
# A115U083AT01005_Dft.bmp
# A115V00SCC03001_Dft.bmp
# A115X02RBJ01002_Dft.bmp
# A116209DAA01001_Dft.bmp
# A116308ABM01002_Dft.bmp
# A116400ABJ05001_Dft.bmp
# A116400FBF01007_Dft.bmp
# A116400FBF04003_Dft.bmp
# A116400FBF04004_Dft.bmp
# A116400FBL01003_Dft.bmp
# A116401TBS01003_Dft.bmp
# A116401XAB05002_Dft.bmp
# A116401XAB05003_Dft.bmp
# A116401XAB06001_Dft.bmp
# A116401YAR03005_Dft.bmp
# A116402JCA01001_Dft.bmp
# A116404CAP01003_Dft.bmp
# A116407FBW01001_Dft.bmp
# A116408AAA02001_Dft.bmp
# A116408JCA01004_Dft.bmp
# A116408KAE05001_Dft.bmp
# A116408KAQ03001_Dft.bmp
# A116408KAR01003_Dft.bmp
# A116408KAR01006_Dft.bmp
# A116408KAR03002_Dft.bmp
# A116409PAH04001_Dft.bmp
# A116501GAU03001_Dft.bmp
# A116501GAW01001_Dft.bmp
# A116501GAW02001_Dft.bmp
# A116501GAW05001_Dft.bmp
# A116501HAR02002_Dft.bmp
# A116501JCC01001_Dft.bmp
# A116702TAG01001_Dft.bmp
# A116703CCG03001_Dft.bmp
# A116703DAH01001_Dft.bmp
# A116707TCJ01002_Dft.bmp
# A116802GBW03001_Dft.bmp
# A116805YBA01002_Dft.bmp
# A116806ABJ03001_Dft.bmp
# A116907JAC06001_Dft.bmp
# A116B01NCC01001_Dft.bmp
# A116B01NCD03001_Dft.bmp

# %%
testFileDir = "test" ## test 圖片路徑
IMAGE_PATHS = [os.path.join(testFileDir, filename) for filename in os.listdir(testFileDir) if filename.endswith(".bmp")]
print(IMAGE_PATHS)
